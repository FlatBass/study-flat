# %%
import numpy as np
arr = np.array([80, 90, 75, 65])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.shape
# Out:
# (4,)

# %%
arr2 = np.array([[1, 2, 3],
                 [4, 5, 6]])

# %%
arr2.shape
# Out:
# (2, 3)

# %%
arr2[0,1]
# Out:
# np.int64(2)

# %%
arr2[:,0]
# Out:
# array([1, 4])

# %% [markdown]
# ### list vs numpy

# %%
# python list : 반복문 필요
[s + 10 for s in [80, 90, 70]]
# Out:
# [90, 100, 80]

# %%
# numpy : 한 번에 (vectorized operation)
np.array([80, 90, 70]) + 10
# Out:
# array([ 90, 100,  80])

# %% [markdown]
# ### pandas와 연결

# %%
import pandas as pd
s = pd.Series([10, 20, 30])
print("numpy array =" ,s.values)
print("numpy.ndarray =",type(s.values))
# Out:
# numpy array = [10 20 30]
# numpy.ndarray = <class 'numpy.ndarray'>
